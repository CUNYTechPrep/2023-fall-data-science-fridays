# %% [markdown]
# # How to handle data in python using Pandas.
# Pandas is like Excel, but does not suck.  Anything you need to do with data, you can do with pandas.  Im going to focus on the 20% of the things that do 80% of the work.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Before we go into coding, lets understand data files first...
# * Who can tell me what a '.csv' file is?

# %%
! open .

# %% [markdown]
# # What is data?
# > A collection of discrete or continuous values that convey information, describing the quantity, quality, fact, statistics, other basic units of meaning, or simply sequences of symbols that may be further interpreted formally.
#
#
# ### Main types of data
#     * Quantitative data is numbers-based, countable, or measurable.  Definition. Quantitative data are data represented numerically, including anything that can be counted, measured, or given a numerical value.
#
#
#     * Qualitative data are data representing information and concepts that are not represented by numbers.  Qualitative data is interpretation-based, descriptive, and relating to language. Quantitative data tells us how many, how much, or how often in calculations. Qualitative data can help us to understand why, how, or what happened behind certain behaviors

# %% [markdown]
# ![types](https://intellspot.com/wp-content/uploads/2018/08/Types-of-Data-Infographic.png) https://www.intellspot.com/data-types/
# ![examples](https://images.ctfassets.net/dkgr2j75jrom/6EkS63alrQ62cHmOClGQnZ/b96701f832d50d393f859d73225c2b57/PillarPage-Qual-Quan__1_-min.png?w=1920&h=979&q=50&fm=webp) https://www.fullstory.com/blog/qualitative-vs-quantitative-data/

# %% [markdown]
# # Lets look at what type of data can live in a '.csv' file

# %% [markdown]
# ![image.png](attachment:32366e65-d4aa-47dd-beea-0ce2e70ba1cf.png) https://pbpython.com/pandas_dtypes.html

# %% [markdown]
# # Importing data
# * If data is seperated by `;`, change to `sep=';'`
# * Shift+Tab is your best friend

# %%
# read in the csv file and store it as a variable named 'df'
df = pd.read_csv('data/listings.csv')

# display just the first 5 rows
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
# 2     Private room     60              29                 50  2019-12-02
# 3  Entire home/apt    175              14                  1  2014-01-02
# 4     Private room     65               2                473  2020-03-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.37                               2               365
# 1               4.75                               1               265
# 2               0.37                               1               365
# 3               0.01                               1               295
# 4               3.44                               1               340

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46527 entries, 0 to 46526
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              46527 non-null  int64
#  1   name                            46509 non-null  object
#  2   host_id                         46527 non-null  int64
#  3   host_name                       46492 non-null  object
#  4   neighbourhood_group             46527 non-null  object
#  5   neighbourhood                   46527 non-null  object
#  6   latitude                        46527 non-null  float64
#  7   longitude                       46527 non-null  float64
#  8   room_type                       46527 non-null  object
#  9   price                           46527 non-null  int64
#  10  minimum_nights                  46527 non-null  int64
#  11  number_of_reviews               46527 non-null  int64
#  12  last_review                     35816 non-null  object
#  13  reviews_per_month               35816 non-null  float64
#  14  calculated_host_listings_count  46527 non-null  int64
#  15  availability_365                46527 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 5.7+ MB

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude        price  \
# count  4.652700e+04  4.652700e+04  46527.000000  46527.000000  46527.00000
# mean   2.299891e+07  8.439186e+07     40.729563    -73.950918    148.60567
# std    1.373123e+07  9.913260e+07      0.054974      0.047562    318.62788
# min    2.595000e+03  2.438000e+03     40.508680    -74.239860      0.00000
# 25%    1.062558e+07  9.194284e+06     40.689945    -73.983170     65.00000
# 50%    2.220528e+07  3.719496e+07     40.724400    -73.955380    100.00000
# 75%    3.575440e+07  1.362274e+08     40.763040    -73.934170    160.00000
# max    4.481801e+07  3.624537e+08     40.911690    -73.712990  10000.00000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    46527.000000       46527.000000       35816.000000
# mean         8.519634          22.767167           0.905802
# std         23.050570          46.603900           1.280898
# min          1.000000           0.000000           0.010000
# 25%          2.000000           1.000000           0.120000
# 50%          3.000000           4.000000           0.380000
# 75%          6.000000          21.000000           1.210000
# max       1250.000000         746.000000          46.240000
#
#        calculated_host_listings_count  availability_365
# count                    46527.000000      46527.000000
# mean                         5.890451        121.142842
# std                         22.731346        142.517750
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         46.000000
# 75%                          2.000000        252.000000
# max                        249.000000        365.000000

# %%
# Lots of options you can set in the pd.set_option class. 
# I am not going to go into this just wanted to show you that it exists

pd.set_option('display.float_format', lambda x: '%.2f' % x)
df.describe()
# Out:
#                id      host_id  latitude  longitude    price  minimum_nights  \
# count    46527.00     46527.00  46527.00   46527.00 46527.00        46527.00
# mean  22998908.54  84391857.82     40.73     -73.95   148.61            8.52
# std   13731229.61  99132599.45      0.05       0.05   318.63           23.05
# min       2595.00      2438.00     40.51     -74.24     0.00            1.00
# 25%   10625576.00   9194284.00     40.69     -73.98    65.00            2.00
# 50%   22205277.00  37194964.00     40.72     -73.96   100.00            3.00
# 75%   35754399.50 136227441.50     40.76     -73.93   160.00            6.00
# max   44818009.00 362453686.00     40.91     -73.71 10000.00         1250.00
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count           46527.00           35816.00                        46527.00
# mean               22.77               0.91                            5.89
# std                46.60               1.28                           22.73
# min                 0.00               0.01                            1.00
# 25%                 1.00               0.12                            1.00
# 50%                 4.00               0.38                            1.00
# 75%                21.00               1.21                            2.00
# max               746.00              46.24                          249.00
#
#        availability_365
# count          46527.00
# mean             121.14
# std              142.52
# min                0.00
# 25%                0.00
# 50%               46.00
# 75%              252.00
# max              365.00

# %% [markdown]
# # Let's find out how to see the 'shape' of our data...

# %%
print(df.shape, len(df))
df.head()
# Out:
# (46527, 16) 46527
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown     40.75     -73.98
# 1  LisaRoxanne            Brooklyn        Clinton Hill     40.69     -73.96
# 2        Garon            Brooklyn  Bedford-Stuyvesant     40.69     -73.96
# 3      Rebecca            Brooklyn         Sunset Park     40.66     -73.99
# 4     Shunichi           Manhattan      Hell's Kitchen     40.76     -73.98
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
# 2     Private room     60              29                 50  2019-12-02
# 3  Entire home/apt    175              14                  1  2014-01-02
# 4     Private room     65               2                473  2020-03-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.37                               2               365
# 1               4.75                               1               265
# 2               0.37                               1               365
# 3               0.01                               1               295
# 4               3.44                               1               340

# %% [markdown]
# # Basic Syntax
# * Select one column
# * Select multiple columns
#    * Must use a list

# %%
# SELECT ONE COLUMN
df['name']
# Out:
# 0                                    Skylit Midtown Castle
# 1        Whole flr w/private bdrm, bath & kitchen(pls r...
# 2                                          BlissArtsSpace!
# 3                 Spacious Brooklyn Duplex, Patio + Garden
# 4                         Large Furnished Room Near B'way
#                                ...
# 46522           Designer Gramercy Studio Townhouse by UNSQ
# 46523    Cozy & comfy apt in the heart of Inwood Manhattan
# 46524    Comfortable safe environment 24hr security camera
# 46525                   Upper West Side studio 86th Street
# 46526    5MIN D/N trains, NEAR THE BEACH, 50’ TO MANHATTAN
# Name: name, Length: 46527, dtype: object

# %%
# SELECT MULTIPLE COLUMNS
# Talk about the index 'column'.., 
cols_to_select = ['id', 'name']

df[ cols_to_select ]
# Out:
#              id                                               name
# 0          2595                              Skylit Midtown Castle
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...
# 2          5121                                    BlissArtsSpace!
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden
# 4          5178                   Large Furnished Room Near B'way
# ...         ...                                                ...
# 46522  44807522         Designer Gramercy Studio Townhouse by UNSQ
# 46523  44807786  Cozy & comfy apt in the heart of Inwood Manhattan
# 46524  44811717  Comfortable safe environment 24hr security camera
# 46525  44814944                 Upper West Side studio 86th Street
# 46526  44818009  5MIN D/N trains, NEAR THE BEACH, 50’ TO MANHATTAN
#
# [46527 rows x 2 columns]

# %% [markdown]
# # Skipping this in lecture for time sake but its here if you want to know how to do it.
# ### Selecting rows:

# %%
# Select in index of rows 0 through 5
df.iloc[0:5]
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown     40.75     -73.98
# 1  LisaRoxanne            Brooklyn        Clinton Hill     40.69     -73.96
# 2        Garon            Brooklyn  Bedford-Stuyvesant     40.69     -73.96
# 3      Rebecca            Brooklyn         Sunset Park     40.66     -73.99
# 4     Shunichi           Manhattan      Hell's Kitchen     40.76     -73.98
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
# 2     Private room     60              29                 50  2019-12-02
# 3  Entire home/apt    175              14                  1  2014-01-02
# 4     Private room     65               2                473  2020-03-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.37                               2               365
# 1               4.75                               1               265
# 2               0.37                               1               365
# 3               0.01                               1               295
# 4               3.44                               1               340

# %%
rows = [0,10,100]
df.iloc[rows]
# Out:
#         id                           name  host_id host_name  \
# 0     2595          Skylit Midtown Castle     2845  Jennifer
# 10    6090  West Village Nest - Superhost    11975     Alina
# 100  29628        Sunny Room in New Condo   127608     Chris
#
#     neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0             Manhattan       Midtown     40.75     -73.98  Entire home/apt
# 10            Manhattan  West Village     40.74     -74.01  Entire home/apt
# 100            Brooklyn  Clinton Hill     40.68     -73.96     Private room
#
#      price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0      175               3                 48  2019-11-04               0.37
# 10      65              30                 29  2020-07-25               0.22
# 100     89               3                281  2020-02-17               2.26
#
#      calculated_host_listings_count  availability_365
# 0                                 2               365
# 10                                1               197
# 100                               1               364

# %%
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown     40.75     -73.98
# 1  LisaRoxanne            Brooklyn        Clinton Hill     40.69     -73.96
# 2        Garon            Brooklyn  Bedford-Stuyvesant     40.69     -73.96
# 3      Rebecca            Brooklyn         Sunset Park     40.66     -73.99
# 4     Shunichi           Manhattan      Hell's Kitchen     40.76     -73.98
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
# 2     Private room     60              29                 50  2019-12-02
# 3  Entire home/apt    175              14                  1  2014-01-02
# 4     Private room     65               2                473  2020-03-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.37                               2               365
# 1               4.75                               1               265
# 2               0.37                               1               365
# 3               0.01                               1               295
# 4               3.44                               1               340

# %% [markdown]
# # Skipping next cell lecture because I like never use it.
# ### Select row and column:

# %%
df.at[ 0, 'name' ]
# Out:
# 'Skylit Midtown Castle'

# %% [markdown]
# # Basic Math
# Lets say we wanted to up the price 100x

# %%
df['new_price'] = df['price'] * 100
df.head(2)
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan       Midtown     40.75     -73.98
# 1  LisaRoxanne            Brooklyn  Clinton Hill     40.69     -73.96
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.37                               2               365
# 1               4.75                               1               265
#
#    new_price
# 0      17500
# 1       7500

# %%
df['price'].mean()
# Out:
# 148.60566982612247

# %% [markdown]
# Let's find the minimum booking amout by multiplying price by minimum_nights
# * note, you can also access columns by using a dot `.`

# %%
df['min_booking_amount'] = df['price'] * df['minimum_nights']
df.head(2)
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan       Midtown     40.75     -73.98
# 1  LisaRoxanne            Brooklyn  Clinton Hill     40.69     -73.96
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.37                               2               365
# 1               4.75                               1               265
#
#    new_price  min_booking_amount
# 0      17500                 525
# 1       7500                  75

# %% [markdown]
# # NOTE show how df is in local memory not in CSV yet.

# %% [markdown]
# # Selecting / Filtering data

# %%
df.head(5)
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown     40.75     -73.98
# 1  LisaRoxanne            Brooklyn        Clinton Hill     40.69     -73.96
# 2        Garon            Brooklyn  Bedford-Stuyvesant     40.69     -73.96
# 3      Rebecca            Brooklyn         Sunset Park     40.66     -73.99
# 4     Shunichi           Manhattan      Hell's Kitchen     40.76     -73.98
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
# 2     Private room     60              29                 50  2019-12-02
# 3  Entire home/apt    175              14                  1  2014-01-02
# 4     Private room     65               2                473  2020-03-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.37                               2               365
# 1               4.75                               1               265
# 2               0.37                               1               365
# 3               0.01                               1               295
# 4               3.44                               1               340
#
#    new_price  min_booking_amount
# 0      17500                 525
# 1       7500                  75
# 2       6000                1740
# 3      17500                2450
# 4       6500                 130

# %%
# Create our select condition.
select_condition = df['neighbourhood_group'] == 'Manhattan'


# Talk about what this is.  A boolean mask. 
select_condition
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 46522     True
# 46523     True
# 46524    False
# 46525     True
# 46526    False
# Name: neighbourhood_group, Length: 46527, dtype: bool

# %%
# Making a new data frame of just Manhattan
select_condition = df['neighbourhood_group'] == 'Manhattan'

df_manhattan = df[ select_condition ]
df_manhattan.head()
# Out:
#      id                                     name  host_id  host_name  \
# 0  2595                    Skylit Midtown Castle     2845   Jennifer
# 4  5178         Large Furnished Room Near B'way　     8967   Shunichi
# 5  5203       Cozy Clean Guest Room - Family Apt     7490  MaryEllen
# 6  5238       Cute & Cozy Lower East Side 1 bdrm     7549        Ben
# 7  5552  Spacious river view in the West Village     8380      Maria
#
#   neighbourhood_group    neighbourhood  latitude  longitude        room_type  \
# 0           Manhattan          Midtown     40.75     -73.98  Entire home/apt
# 4           Manhattan   Hell's Kitchen     40.76     -73.98     Private room
# 5           Manhattan  Upper West Side     40.80     -73.97     Private room
# 6           Manhattan        Chinatown     40.71     -73.99  Entire home/apt
# 7           Manhattan     West Village     40.74     -74.01  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    175               3                 48  2019-11-04               0.37
# 4     65               2                473  2020-03-15               3.44
# 5     75               2                118  2017-07-21               0.89
# 6    140               1                161  2019-07-29               1.21
# 7    160               3                 66  2019-08-10               0.49
#
#    calculated_host_listings_count  availability_365  new_price  \
# 0                               2               365      17500
# 4                               1               340       6500
# 5                               1                 0       7500
# 6                               4               274      14000
# 7                               1               178      16000
#
#    min_booking_amount
# 0                 525
# 4                 130
# 5                 150
# 6                 140
# 7                 480

# %%
# SIDE NOTE INTERRUPTION
## MY FAVORITE POANDAS FUNCTION .value_counts()
# This is great for sanity checks

df.neighbourhood_group.value_counts()
# Out:
# Manhattan        20580
# Brooklyn         18632
# Queens            5791
# Bronx             1183
# Staten Island      341
# Name: neighbourhood_group, dtype: int64

# %%
df_manhattan.neighbourhood_group.value_counts()
# Out:
# Manhattan    20580
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# # Using more than one filter / selector

# %%
# Select Brooklyn
condition_1 = df['neighbourhood_group'] == 'Brooklyn'

# Select Prices that are higher than 500
condition_2 = df['price'] > 500

# Select all data that meets both requirments
bk_high = df[ condition_1 & condition_2 ]
bk_high.head()
# Out:
#          id                                 name  host_id  \
# 67    19601  perfect for a family or small group    74303
# 125   38663     Luxury Brownstone in Boerum Hill   165789
# 288   89427                 The Brooklyn Waverly   116599
# 308  103311    2 BR w/ Terrace @ Box House Hotel   417504
# 355  141335               Architect's Brownstone   687361
#
#                host_name neighbourhood_group     neighbourhood  latitude  \
# 67                Maggie            Brooklyn  Brooklyn Heights     40.70
# 125                Sarah            Brooklyn       Boerum Hill     40.69
# 288                 Sahr            Brooklyn      Clinton Hill     40.69
# 308  The Box House Hotel            Brooklyn        Greenpoint     40.74
# 355                 Orna            Brooklyn        Park Slope     40.68
#
#      longitude        room_type  price  minimum_nights  number_of_reviews  \
# 67      -73.99  Entire home/apt   2000               1                 25
# 125     -73.98  Entire home/apt    650               3                 23
# 288     -73.97  Entire home/apt    650               5                  0
# 308     -73.95     Private room    599               3                  9
# 355     -73.98  Entire home/apt    685               1                 35
#
#     last_review  reviews_per_month  calculated_host_listings_count  \
# 67   2016-08-04               0.21                               1
# 125  2018-12-31               0.23                               1
# 288         NaN                NaN                               3
# 308  2018-05-19               0.08                              28
# 355  2018-01-13               0.35                               1
#
#      availability_365  new_price  min_booking_amount
# 67                134     200000                2000
# 125               365      65000                1950
# 288               364      65000                3250
# 308               215      59900                1797
# 355               365      68500                 685

# %% [markdown]
# ## Using 'or' statments
# * What if we want to find all listings in Midtown or DUMBO
# * The 'or' in python is the pipe thing `|`

# %%
condition_1 = df.neighbourhood == 'Midtown'

condition_2 = df.neighbourhood == 'DUMBO'

# Select all data that meets condition 1 or condition 2
df[ condition_1 | condition_2]['neighbourhood'].value_counts()
# Out:
# Midtown    1636
# DUMBO        37
# Name: neighbourhood, dtype: int64

# %% [markdown]
# # Why doesn't this work..?

# %%
# Why doesn't this work..?

condition_1 = df.neighbourhood == 'Midtown'

condition_2 = df.neighbourhood == 'DUMBO'

# Select all data that meets condition 1 or condition 2
df[ condition_1 & condition_2]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, new_price, min_booking_amount]
# Index: []

# %% [markdown]
# ## Using `.isin`. A very handy selector tool.

# %%
# List of neighborhoods we want to select
neighborhoods = ['Midtown', 'DUMBO', 'Queens']

# Create our select condition aka 'boolean mask'
condition = df.neighbourhood.isin(neighborhoods)

# Display the filtered data
df[condition]['neighbourhood'].value_counts()
# Out:
# Midtown    1636
# DUMBO        37
# Name: neighbourhood, dtype: int64

# %%
list_of_hoods = ['Sunnyside', 'Woodside']

select_statement = df.neighbourhood.isin(list_of_hoods)

df[select_statement]
# Out:
#              id                                               name    host_id  \
# 60        18195                 King of Queens w/ Private Bathroom      70091
# 61        18198                              Little King of Queens      70091
# 130       39593                  A room of own w/ a Manhattan view     110506
# 473      209310   Sunnyside NYC/ AC room/ city views/ near Midtown    1031148
# 614      263776                City Skyline Views from every room!    1384111
# ...         ...                                                ...        ...
# 46293  44579912   Antique style apartment/Comfortable area@Queens.  200239515
# 46294  44580012   It takes 30 minutes approximately for Manhattan.  334163301
# 46295  44580140     Cozy room&house in Woodside, comfortable are!!   19303369
# 46341  44628752  Gorgeous zen huge 2 bedroom apartment in Sunny...   31913440
# 46426  44677711               Great location in Woodside Queens NY   26055080
#
#       host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 60       Justin              Queens      Woodside     40.75     -73.91
# 61       Justin              Queens      Woodside     40.75     -73.90
# 130       Myung              Queens     Sunnyside     40.75     -73.92
# 473       Iulia              Queens     Sunnyside     40.74     -73.92
# 614      Joanne              Queens     Sunnyside     40.75     -73.92
# ...         ...                 ...           ...       ...        ...
# 46293     Shogo              Queens      Woodside     40.74     -73.90
# 46294      Soya              Queens      Woodside     40.74     -73.90
# 46295    Hiroki              Queens      Woodside     40.74     -73.90
# 46341  Courtney              Queens     Sunnyside     40.74     -73.93
# 46426     Danny              Queens      Woodside     40.75     -73.90
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 60        Private room     90               7                 22  2020-05-16
# 61        Private room     75              14                 27  2020-04-30
# 130       Private room     73              30                 29  2019-12-22
# 473       Private room     50               1                281  2020-03-16
# 614       Private room     83               2                 95  2019-01-02
# ...                ...    ...             ...                ...         ...
# 46293     Private room     28              20                  0         NaN
# 46294     Private room     25              28                  0         NaN
# 46295     Private room     25              30                  0         NaN
# 46341  Entire home/apt     90               3                  0         NaN
# 46426     Private room     49               2                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 60                  0.17                               2               332
# 61                  0.21                               2                14
# 130                 0.24                               1                74
# 473                 2.74                               2               102
# 614                 0.89                               2                 0
# ...                  ...                             ...               ...
# 46293                NaN                              37                31
# 46294                NaN                              83                31
# 46295                NaN                              98                31
# 46341                NaN                               3                63
# 46426                NaN                               4               363
#
#        new_price  min_booking_amount
# 60          9000                 630
# 61          7500                1050
# 130         7300                2190
# 473         5000                  50
# 614         8300                 166
# ...          ...                 ...
# 46293       2800                 560
# 46294       2500                 700
# 46295       2500                 750
# 46341       9000                 270
# 46426       4900                  98
#
# [726 rows x 18 columns]

# %%
# How would we do a sanity check and see if it only selected Sunnside and Woodside?
## ASK STUDENTS.

# %%
# Inverse selections

list_of_hoods = ['Sunnyside', 'Woodside']

select_statement = df.neighbourhood.isin(list_of_hoods)


# using the '~' will tell it to select the opposite/inverse of the select statement.
df[~select_statement].head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown     40.75     -73.98
# 1  LisaRoxanne            Brooklyn        Clinton Hill     40.69     -73.96
# 2        Garon            Brooklyn  Bedford-Stuyvesant     40.69     -73.96
# 3      Rebecca            Brooklyn         Sunset Park     40.66     -73.99
# 4     Shunichi           Manhattan      Hell's Kitchen     40.76     -73.98
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
# 2     Private room     60              29                 50  2019-12-02
# 3  Entire home/apt    175              14                  1  2014-01-02
# 4     Private room     65               2                473  2020-03-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.37                               2               365
# 1               4.75                               1               265
# 2               0.37                               1               365
# 3               0.01                               1               295
# 4               3.44                               1               340
#
#    new_price  min_booking_amount
# 0      17500                 525
# 1       7500                  75
# 2       6000                1740
# 3      17500                2450
# 4       6500                 130

# %% [markdown]
# # Assigning values to filtered columns using `np.where()`
# * np.where is a handy tool that takes in a condition statement, followed by what value to set when condition is true, and then what value to set when condition is false.
# * `np.where(condition, when_true, when_false)`

# %% [markdown]
# ### We want a new column that whenever a listing is in Williamsburg, set it equal to 1, else, 0.

# %%
# c1 = df['neighbourhood'] == 'Williamsburg'
c1 = df['min_booking_amount'] > 100

df['is_expensive'] = np.where( c1, 'expensive', 'cheap')

df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown     40.75     -73.98
# 1  LisaRoxanne            Brooklyn        Clinton Hill     40.69     -73.96
# 2        Garon            Brooklyn  Bedford-Stuyvesant     40.69     -73.96
# 3      Rebecca            Brooklyn         Sunset Park     40.66     -73.99
# 4     Shunichi           Manhattan      Hell's Kitchen     40.76     -73.98
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    175               3                 48  2019-11-04
# 1  Entire home/apt     75               1                340  2020-08-01
# 2     Private room     60              29                 50  2019-12-02
# 3  Entire home/apt    175              14                  1  2014-01-02
# 4     Private room     65               2                473  2020-03-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.37                               2               365
# 1               4.75                               1               265
# 2               0.37                               1               365
# 3               0.01                               1               295
# 4               3.44                               1               340
#
#    new_price  min_booking_amount is_expensive
# 0      17500                 525    expensive
# 1       7500                  75        cheap
# 2       6000                1740    expensive
# 3      17500                2450    expensive
# 4       6500                 130    expensive

# %%
# You can do it with multiple conditions as well...

# First select condition.
c1 = df['neighbourhood'] == 'Williamsburg'

# Second select condition.
c2 = df['room_type'] == 'Private room'

# Set equal to one when both conditions are true, and zero when not true.
df['private_room_in_williamsburg'] =  np.where( c1 & c2, 1, 0 )

# Sanity check to view if our assignment worked correctly.
select_statement = df['private_room_in_williamsburg'] == 1

new_df = df[  select_statement ]

df['select_statement'] = select_statement

df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown     40.75     -73.98
# 1  LisaRoxanne            Brooklyn        Clinton Hill     40.69     -73.96
# 2        Garon            Brooklyn  Bedford-Stuyvesant     40.69     -73.96
# 3      Rebecca            Brooklyn         Sunset Park     40.66     -73.99
# 4     Shunichi           Manhattan      Hell's Kitchen     40.76     -73.98
#
#          room_type  price  ...  number_of_reviews  last_review  \
# 0  Entire home/apt    175  ...                 48   2019-11-04
# 1  Entire home/apt     75  ...                340   2020-08-01
# 2     Private room     60  ...                 50   2019-12-02
# 3  Entire home/apt    175  ...                  1   2014-01-02
# 4     Private room     65  ...                473   2020-03-15
#
#   reviews_per_month  calculated_host_listings_count  availability_365  \
# 0              0.37                               2               365
# 1              4.75                               1               265
# 2              0.37                               1               365
# 3              0.01                               1               295
# 4              3.44                               1               340
#
#    new_price  min_booking_amount  is_expensive private_room_in_williamsburg  \
# 0      17500                 525     expensive                            0
# 1       7500                  75         cheap                            0
# 2       6000                1740     expensive                            0
# 3      17500                2450     expensive                            0
# 4       6500                 130     expensive                            0
#
#    select_statement
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
#
# [5 rows x 21 columns]

# %% [markdown]
# # Applying a functions to a column // skip to Grouping if running low on time.

# %%
def half_number(input_number):
    output_number = input_number / 2
    return output_number

# %%
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown     40.75     -73.98
# 1  LisaRoxanne            Brooklyn        Clinton Hill     40.69     -73.96
# 2        Garon            Brooklyn  Bedford-Stuyvesant     40.69     -73.96
# 3      Rebecca            Brooklyn         Sunset Park     40.66     -73.99
# 4     Shunichi           Manhattan      Hell's Kitchen     40.76     -73.98
#
#          room_type  price  ...  number_of_reviews  last_review  \
# 0  Entire home/apt    175  ...                 48   2019-11-04
# 1  Entire home/apt     75  ...                340   2020-08-01
# 2     Private room     60  ...                 50   2019-12-02
# 3  Entire home/apt    175  ...                  1   2014-01-02
# 4     Private room     65  ...                473   2020-03-15
#
#   reviews_per_month  calculated_host_listings_count  availability_365  \
# 0              0.37                               2               365
# 1              4.75                               1               265
# 2              0.37                               1               365
# 3              0.01                               1               295
# 4              3.44                               1               340
#
#    new_price  min_booking_amount  surcharge  private_room_in_williamsburg  \
# 0      17500                 525       1000                             0
# 1       7500                  75         75                             0
# 2       6000                1740       1000                             0
# 3      17500                2450       1000                             0
# 4       6500                 130       1000                             0
#
#    select_statement
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
#
# [5 rows x 21 columns]

# %%
df['sale_price'] = df['price'].apply(half_number )
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown     40.75     -73.98
# 1  LisaRoxanne            Brooklyn        Clinton Hill     40.69     -73.96
# 2        Garon            Brooklyn  Bedford-Stuyvesant     40.69     -73.96
# 3      Rebecca            Brooklyn         Sunset Park     40.66     -73.99
# 4     Shunichi           Manhattan      Hell's Kitchen     40.76     -73.98
#
#          room_type  price  ...  last_review  reviews_per_month  \
# 0  Entire home/apt    175  ...   2019-11-04               0.37
# 1  Entire home/apt     75  ...   2020-08-01               4.75
# 2     Private room     60  ...   2019-12-02               0.37
# 3  Entire home/apt    175  ...   2014-01-02               0.01
# 4     Private room     65  ...   2020-03-15               3.44
#
#   calculated_host_listings_count  availability_365  new_price  \
# 0                              2               365      17500
# 1                              1               265       7500
# 2                              1               365       6000
# 3                              1               295      17500
# 4                              1               340       6500
#
#    min_booking_amount  surcharge  private_room_in_williamsburg  \
# 0                 525       1000                             0
# 1                  75         75                             0
# 2                1740       1000                             0
# 3                2450       1000                             0
# 4                 130       1000                             0
#
#    select_statement  sale_price
# 0             False       87.50
# 1             False       37.50
# 2             False       30.00
# 3             False       87.50
# 4             False       32.50
#
# [5 rows x 22 columns]

# %%
# How to select just places that are furnished.

def my_function(x):
    if 'Furnished' in str(x):
        return 1
    else:
        return 0

df['is_furnished'] = df['name'].apply( my_function )

df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown     40.75     -73.98
# 1  LisaRoxanne            Brooklyn        Clinton Hill     40.69     -73.96
# 2        Garon            Brooklyn  Bedford-Stuyvesant     40.69     -73.96
# 3      Rebecca            Brooklyn         Sunset Park     40.66     -73.99
# 4     Shunichi           Manhattan      Hell's Kitchen     40.76     -73.98
#
#          room_type  price  ...  last_review  reviews_per_month  \
# 0  Entire home/apt    175  ...   2019-11-04               0.37
# 1  Entire home/apt     75  ...   2020-08-01               4.75
# 2     Private room     60  ...   2019-12-02               0.37
# 3  Entire home/apt    175  ...   2014-01-02               0.01
# 4     Private room     65  ...   2020-03-15               3.44
#
#   calculated_host_listings_count  availability_365  new_price  \
# 0                              2               365      17500
# 1                              1               265       7500
# 2                              1               365       6000
# 3                              1               295      17500
# 4                              1               340       6500
#
#    min_booking_amount  is_expensive  private_room_in_williamsburg  \
# 0                 525     expensive                             0
# 1                  75         cheap                             0
# 2                1740     expensive                             0
# 3                2450     expensive                             0
# 4                 130     expensive                             0
#
#   select_statement  is_furnished
# 0            False             0
# 1            False             0
# 2            False             0
# 3            False             0
# 4            False             1
#
# [5 rows x 22 columns]

# %% [markdown]
# # Grouping

# %% [markdown]
# <img src='https://i.stack.imgur.com/sgCn1.jpg'>

# %%
df.head().T
# Out:
#                                                     0
# id                                               2595  \
# name                            Skylit Midtown Castle
# host_id                                          2845
# host_name                                    Jennifer
# neighbourhood_group                         Manhattan
# neighbourhood                                 Midtown
# latitude                                     40.75362
# longitude                                   -73.98377
# room_type                             Entire home/apt
# price                                             175
# minimum_nights                                      3
# number_of_reviews                                  48
# last_review                                2019-11-04
# reviews_per_month                                0.37
# calculated_host_listings_count                      2
# availability_365                                  365
# new_price                                       17500
# min_booking_amount                                525
# is_furnished                                        0
# surcharge                                        1000
# private_room_in_williamsburg                        0
# select_statement                                False
# sale_price                                       87.5
# cut_price                                        87.5
#
#                                                                                 1
# id                                                                           3831  \
# name                            Whole flr w/private bdrm, bath & kitchen(pls r...
# host_id                                                                      4869
# host_name                                                             LisaRoxanne
# neighbourhood_group                                                      Brooklyn
# neighbourhood                                                        Clinton Hill
# latitude                                                                 40.68514
# longitude                                                               -73.95976
# room_type                                                         Entire home/apt
# price                                                                          75
# minimum_nights                                                                  1
# number_of_reviews                                                             340
# last_review                                                            2020-08-01
# reviews_per_month                                                            4.75
# calculated_host_listings_count                                                  1
# availability_365                                                              265
# new_price                                                                    7500
# min_booking_amount                                                             75
# is_furnished                                                                    0
# surcharge                                                                      75
# private_room_in_williamsburg                                                    0
# select_statement                                                            False
# sale_price                                                                   37.5
# cut_price                                                                    37.5
#
#                                                  2
# id                                            5121  \
# name                               BlissArtsSpace!
# host_id                                       7356
# host_name                                    Garon
# neighbourhood_group                       Brooklyn
# neighbourhood                   Bedford-Stuyvesant
# latitude                                  40.68688
# longitude                                -73.95596
# room_type                             Private room
# price                                           60
# minimum_nights                                  29
# number_of_reviews                               50
# last_review                             2019-12-02
# reviews_per_month                             0.37
# calculated_host_listings_count                   1
# availability_365                               365
# new_price                                     6000
# min_booking_amount                            1740
# is_furnished                                     0
# surcharge                                     1000
# private_room_in_williamsburg                     0
# select_statement                             False
# sale_price                                    30.0
# cut_price                                     30.0
#
#                                                                        3
# id                                                                  5136  \
# name                            Spacious Brooklyn Duplex, Patio + Garden
# host_id                                                             7378
# host_name                                                        Rebecca
# neighbourhood_group                                             Brooklyn
# neighbourhood                                                Sunset Park
# latitude                                                         40.6612
# longitude                                                      -73.99423
# room_type                                                Entire home/apt
# price                                                                175
# minimum_nights                                                        14
# number_of_reviews                                                      1
# last_review                                                   2014-01-02
# reviews_per_month                                                   0.01
# calculated_host_listings_count                                         1
# availability_365                                                     295
# new_price                                                          17500
# min_booking_amount                                                  2450
# is_furnished                                                           0
# surcharge                                                           1000
# private_room_in_williamsburg                                           0
# select_statement                                                   False
# sale_price                                                          87.5
# cut_price                                                           87.5
#
#                                                                4
# id                                                          5178
# name                            Large Furnished Room Near B'way
# host_id                                                     8967
# host_name                                               Shunichi
# neighbourhood_group                                    Manhattan
# neighbourhood                                     Hell's Kitchen
# latitude                                                40.76489
# longitude                                              -73.98493
# room_type                                           Private room
# price                                                         65
# minimum_nights                                                 2
# number_of_reviews                                            473
# last_review                                           2020-03-15
# reviews_per_month                                           3.44
# calculated_host_listings_count                                 1
# availability_365                                             340
# new_price                                                   6500
# min_booking_amount                                           130
# is_furnished                                                   1
# surcharge                                                   1000
# private_room_in_williamsburg                                   0
# select_statement                                           False
# sale_price                                                  32.5
# cut_price                                                   32.5

# %% [markdown]
# Doing a groupby does nothing unless you apply a function to a column of the groupby object.

# %%
group_by_object = df.groupby('neighbourhood_group')
print(group_by_object)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x13e83f850>

# %% [markdown]
# ## After the groupby, select a column then select the function you want to perform on said column.

# %%
gb = df.groupby('neighbourhood_group')
print(gb)

gb['price'].mean()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x13ee2a650>
# neighbourhood_group
# Bronx            92.75
# Brooklyn        120.23
# Manhattan       191.88
# Queens           99.75
# Staten Island   110.95
# Name: price, dtype: float64

# %% [markdown]
# # You can use `.agg` to do multiple functions on said column.

# %%
gb = df.groupby('neighbourhood_group')
gb['price'].agg( ['count', 'min', 'max', 'mean', 'median', 'std', 'sum'] )
# Out:
#                      count  min    max   mean  median    std      sum
# neighbourhood_group
# Bronx                 1183   16   1404  92.75   69.00  95.79   109725
# Brooklyn             18632    0  10000 120.23   90.00 180.14  2240037
# Manhattan            20580    0  10000 191.88  129.00 428.68  3948900
# Queens                5791    0  10000  99.75   70.00 207.65   577681
# Staten Island          341   19   1200 110.95   79.00 122.68    37833

# %% [markdown]
# # You can only groupy by categorical values. And you can only apply the aggerate function to continous values.

# %% [markdown]
# # Double groupby

# %%
groupby_cols = ['neighbourhood_group', 'room_type']
gb = df.groupby(groupby_cols)
gb['price'].mean()
# Out:
# neighbourhood_group  room_type
# Bronx                Entire home/apt   138.00
#                      Private room       68.42
#                      Shared room        66.39
# Brooklyn             Entire home/apt   171.59
#                      Hotel room        147.30
#                      Private room       71.29
#                      Shared room        57.87
# Manhattan            Entire home/apt   231.34
#                      Hotel room        292.52
#                      Private room      128.28
#                      Shared room       111.74
# Queens               Entire home/apt   150.17
#                      Hotel room        139.06
#                      Private room       69.97
#                      Shared room        89.89
# Staten Island        Entire home/apt   151.72
#                      Private room       70.31
#                      Shared room        46.00
# Name: price, dtype: float64

# %% [markdown]
# # Making a DataFrame out of a groupby
# * This is somewhat nuanced, but something I find people struggle on and is very handy to know how to do.

# %%
# Do your group by
gb = df.groupby('neighbourhood_group')['price'].mean()
# # # Convert it to a DataFrame
new_df = pd.DataFrame(gb)

# # # # # Reset the index
new_df = new_df.reset_index()

# # # # Check it out
new_df
# Out:
#   neighbourhood_group  price
# 0               Bronx  92.75
# 1            Brooklyn 120.23
# 2           Manhattan 191.88
# 3              Queens  99.75
# 4       Staten Island 110.95

# %% [markdown]
# # Very helpful tools
# * `df.describe()`
# * `df.info`
# * `df.shape`
# * `df['column'].value_counts()`
# * `df['column'].apply(function)`
# * `df.dropna(subset=[columns])`

# %%
df.describe()
# Out:
#                id      host_id  latitude  longitude    price  minimum_nights  \
# count    46527.00     46527.00  46527.00   46527.00 46527.00        46527.00
# mean  22998908.54  84391857.82     40.73     -73.95   148.61            8.52
# std   13731229.61  99132599.45      0.05       0.05   318.63           23.05
# min       2595.00      2438.00     40.51     -74.24     0.00            1.00
# 25%   10625576.00   9194284.00     40.69     -73.98    65.00            2.00
# 50%   22205277.00  37194964.00     40.72     -73.96   100.00            3.00
# 75%   35754399.50 136227441.50     40.76     -73.93   160.00            6.00
# max   44818009.00 362453686.00     40.91     -73.71 10000.00         1250.00
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count           46527.00           35816.00                        46527.00
# mean               22.77               0.91                            5.89
# std                46.60               1.28                           22.73
# min                 0.00               0.01                            1.00
# 25%                 1.00               0.12                            1.00
# 50%                 4.00               0.38                            1.00
# 75%                21.00               1.21                            2.00
# max               746.00              46.24                          249.00
#
#        availability_365  new_price  min_booking_amount  \
# count          46527.00   46527.00            46527.00
# mean             121.14   14860.57             1372.55
# std              142.52   31862.79            10460.96
# min                0.00       0.00                0.00
# 25%                0.00    6500.00              140.00
# 50%               46.00   10000.00              320.00
# 75%              252.00   16000.00              850.00
# max              365.00 1000000.00          1170000.00
#
#        private_room_in_williamsburg  is_furnished
# count                      46527.00      46527.00
# mean                           0.04          0.01
# std                            0.19          0.08
# min                            0.00          0.00
# 25%                            0.00          0.00
# 50%                            0.00          0.00
# 75%                            0.00          0.00
# max                            1.00          1.00

# %%
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown     40.75     -73.98
# 1  LisaRoxanne            Brooklyn        Clinton Hill     40.69     -73.96
# 2        Garon            Brooklyn  Bedford-Stuyvesant     40.69     -73.96
# 3      Rebecca            Brooklyn         Sunset Park     40.66     -73.99
# 4     Shunichi           Manhattan      Hell's Kitchen     40.76     -73.98
#
#          room_type  price  ...  last_review  reviews_per_month  \
# 0  Entire home/apt    175  ...   2019-11-04               0.37
# 1  Entire home/apt     75  ...   2020-08-01               4.75
# 2     Private room     60  ...   2019-12-02               0.37
# 3  Entire home/apt    175  ...   2014-01-02               0.01
# 4     Private room     65  ...   2020-03-15               3.44
#
#   calculated_host_listings_count  availability_365  new_price  \
# 0                              2               365      17500
# 1                              1               265       7500
# 2                              1               365       6000
# 3                              1               295      17500
# 4                              1               340       6500
#
#    min_booking_amount  is_expensive  private_room_in_williamsburg  \
# 0                 525     expensive                             0
# 1                  75         cheap                             0
# 2                1740     expensive                             0
# 3                2450     expensive                             0
# 4                 130     expensive                             0
#
#   select_statement  is_furnished
# 0            False             0
# 1            False             0
# 2            False             0
# 3            False             0
# 4            False             1
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46527 entries, 0 to 46526
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              46527 non-null  int64
#  1   name                            46509 non-null  object
#  2   host_id                         46527 non-null  int64
#  3   host_name                       46492 non-null  object
#  4   neighbourhood_group             46527 non-null  object
#  5   neighbourhood                   46527 non-null  object
#  6   latitude                        46527 non-null  float64
#  7   longitude                       46527 non-null  float64
#  8   room_type                       46527 non-null  object
#  9   price                           46527 non-null  int64
#  10  minimum_nights                  46527 non-null  int64
#  11  number_of_reviews               46527 non-null  int64
#  12  last_review                     35816 non-null  object
#  13  reviews_per_month               35816 non-null  float64
#  14  calculated_host_listings_count  46527 non-null  int64
#  15  availability_365                46527 non-null  int64
#  16  new_price                       46527 non-null  int64
#  17  min_booking_amount              46527 non-null  int64
#  18  is_expensive                    46527 non-null  object
#  19  private_room_in_williamsburg    46527 non-null  int64
#  20  select_statement                46527 non-null  bool
#  21  is_furnished                    46527 non-null  int64
# dtypes: bool(1), float64(3), int64(11), object(7)
# memory usage: 7.5+ MB

# %% [markdown]
# # How to find percentages of the whole using `value_counts`

# %%
dfv = df.neighbourhood_group.value_counts() 
dfv
# Out:
# Manhattan        20580
# Brooklyn         18632
# Queens            5791
# Bronx             1183
# Staten Island      341
# Name: neighbourhood_group, dtype: int64

# %%
dfp = df.neighbourhood_group.value_counts(normalize=True) 
dfp
# Out:
# Manhattan       0.44
# Brooklyn        0.40
# Queens          0.12
# Bronx           0.03
# Staten Island   0.01
# Name: neighbourhood_group, dtype: float64

# %% [markdown]
# # Joins

# %% [markdown]
# ![Image](https://i.stack.imgur.com/UI25E.jpg)

# %% [markdown]
# # In pandas its MERGE not JOIN for some odd reason.

# %%
dfprices = pd.read_csv('data/prices.csv')
dfprices
# Out:
#   neighbourhood_group   mean_price
# 0               Bronx        92.75
# 1            Brooklyn       120.23
# 2           Manhattan       191.88
# 3              Queens        99.75
# 4       Staten Island       110.95

# %%
# Why is this funky and how do we fix it
dflistings = pd.read_csv('data/n_listings.csv')
dflistings
# Out:
#   neighbourhood_group  n_listings
# 0               Bronx        1183
# 1            Brooklyn       18632
# 2           Manhattan       20580
# 3          LongIsland        4121

# %%
# Merge defaults to an inner-join
new_df = pd.merge(dfprices, dflistings, on='neighbourhood_group')
new_df
# Out:
#   neighbourhood_group   mean_price  n_listings
# 0               Bronx        92.75        1183
# 1            Brooklyn       120.23       18632
# 2           Manhattan       191.88       20580

# %%
# Doing a outer join keeps all values in the left table
dfjoined = pd.merge(dfprices, 
                    dflistings, 
                    on='neighbourhood_group', 
                    how='left')

dfjoined
# Out:
#   neighbourhood_group   mean_price  n_listings
# 0               Bronx        92.75     1183.00
# 1            Brooklyn       120.23    18632.00
# 2           Manhattan       191.88    20580.00
# 3              Queens        99.75         NaN
# 4       Staten Island       110.95         NaN

# %%
pd.merge??

# %% [markdown]
# # Exporting data
# * Almost always use `index=False` when saving your csv

# %%
# This is the name of your new file
save_as = 'my-data-file.csv'

# This is the method you use, DONT FORGET INDEX=FALSE!
dfjoined.to_csv(save_as, index=False)

# %%
# Another fun way to get your data out.
dfjoined.to_clipboard(index=False)
